# %%
import pandas as pd
import sqlite3 as sql
from pathlib import Path
import requests
# from IPython.display import Image
# import config

# census_api_key = '&key=' + config.census_api_key

poverty_2020 = 'https://api.census.gov/data/timeseries/poverty/saipe?get=NAME,SAEPOVRTALL_PT&for=COUNTY:*&time=2020'

table_maker = poverty_2020

response = requests.get(table_maker)
print(response)
res = response.json()
res = pd.DataFrame(res)
res['FIPS'] = res[3] + res[4]
res = res.rename(columns = {0:'County Name', 1:'All ages in poverty Rate Estimate', 2:'Year', 3:'Sate', 4:'County', 5:'FIPS'})
res = res.drop(res.index[0])
file_name = 'poverty_2020'
filepath = r'..\cpst_tables\tbl-' + file_name + '.csv'
res.to_csv(filepath, index=False)
# Out:
# <Response [200]>

# %%
res
# Out:
#             County Name All ages in poverty Rate Estimate  Year Sate County  \
# 1        Autauga County                              11.2  2020   01    001
# 2        Baldwin County                               8.9  2020   01    003
# 3        Barbour County                              25.5  2020   01    005
# 4           Bibb County                              17.8  2020   01    007
# 5         Blount County                              13.1  2020   01    009
# ...                 ...                               ...   ...  ...    ...
# 3139  Sweetwater County                               7.6  2020   56    037
# 3140       Teton County                               5.2  2020   56    039
# 3141       Uinta County                               8.5  2020   56    041
# 3142    Washakie County                               9.7  2020   56    043
# 3143      Weston County                              10.6  2020   56    045
#
#        FIPS
# 1     01001
# 2     01003
# 3     01005
# 4     01007
# 5     01009
# ...     ...
# 3139  56037
# 3140  56039
# 3141  56041
# 3142  56043
# 3143  56045
#
# [3143 rows x 6 columns]
